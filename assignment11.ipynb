# %% [markdown]
# # EMPLOYEE DATA ANALYSIS PROJECT

# %%
import pandas as pd
import numpy as np

# %%
print("\n===== LOADING DATASET =====")
# Out:
# ===== LOADING DATASET =====

# %% [markdown]
# # LOAD DATASET

# %%
emp_df = pd.read_csv(r"C:\Users\LENOVO\OneDrive\Documents\employees.csv")

print("\nFirst 5 rows:")
print(emp_df.head())

print("\nLast 5 rows:")
print(emp_df.tail())
# Out:
# First 5 rows:
#   First Name  Gender Start Date Last Login Time  Salary  Bonus %  \
# 0    Douglas    Male   8/6/1993        12:42 PM   97308    6.945
# 1     Thomas    Male  3/31/1996         6:53 AM   61933    4.170
# 2      Maria  Female  4/23/1993        11:17 AM  130590   11.858
# 3      Jerry    Male   3/4/2005         1:00 PM  138705    9.340
# 4      Larry    Male  1/24/2002         4:47 PM  101004    1.389
#
#   Senior Management             Team
# 0              True        Marketing
# 1              True              NaN
# 2             False          Finance
# 3              True          Finance
# 4              True  Client Services
#
# Last 5 rows:
#     First Name  Gender  Start Date Last Login Time  Salary  Bonus %  \
# 96       Randy    Male   9/27/1980        12:00 AM  116708    1.427
# 97      Samuel    Male   8/25/1997        12:00 AM  118679   15.688
# 98      Andrea  Female   8/12/1982        12:00 AM  108037   12.241
# 99       David    Male  11/29/1999        12:00 AM   42407   17.425
# 100  Christina  Female    8/6/2002        12:00 AM  118784    5.093
#
#     Senior Management             Team
# 96               True  Human Resources
# 97               True            Sales
# 98              False        Marketing
# 99              False  Client Services
# 100              True        Marketing

# %% [markdown]
# # BASIC INFORMATION

# %%
print("\nShape of dataset:")
print(emp_df.shape)

print("\nData types:")
print(emp_df.dtypes)

print("\nInfo:")
print(emp_df.info())
# Out:
# Shape of dataset:
# (101, 8)
#
# Data types:
# First Name            object
# Gender                object
# Start Date            object
# Last Login Time       object
# Salary                 int64
# Bonus %              float64
# Senior Management     object
# Team                  object
# dtype: object
#
# Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 101 entries, 0 to 100
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   First Name         101 non-null    object
#  1   Gender             101 non-null    object
#  2   Start Date         101 non-null    object
#  3   Last Login Time    101 non-null    object
#  4   Salary             101 non-null    int64
#  5   Bonus %            101 non-null    float64
#  6   Senior Management  100 non-null    object
#  7   Team               100 non-null    object
# dtypes: float64(1), int64(1), object(6)
# memory usage: 6.4+ KB
# None

# %% [markdown]
# # MISSING VALUES

# %%
print("\nMissing values per column:")
print(emp_df.isnull().sum())

emp_df['Salary'] = emp_df['Salary'].fillna(emp_df['Salary'].mean())
emp_df['Team'] = emp_df['Team'].fillna("No Team")
# Out:
# Missing values per column:
# First Name           0
# Gender               0
# Start Date           0
# Last Login Time      0
# Salary               0
# Bonus %              0
# Senior Management    1
# Team                 1
# dtype: int64

# %% [markdown]
# # DUPLICATES

# %%
print("\nDuplicate rows:", emp_df.duplicated().sum())
# Out:
# Duplicate rows: 0

# %% [markdown]
# # FEATURE ENGINEERING

# %%
emp_df['Salary in Thousands'] = emp_df['Salary'] / 1000
emp_df['Bonus Amount'] = emp_df['Salary'] * emp_df['Bonus %'] / 100

# %% [markdown]
# # STRING OPERATIONS

# %%
emp_df['Team'] = emp_df['Team'].astype(str).str.lower()

print("\nEmployees whose name starts with J:")
print(emp_df[emp_df['First Name'].str.startswith('J', na=False)])
# Out:
# Employees whose name starts with J:
#    First Name  Gender  Start Date Last Login Time  Salary  Bonus %  \
# 3       Jerry    Male    3/4/2005         1:00 PM  138705    9.340
# 15      James    Male    9/2/2008         6:00 AM   64505    8.339
# 23      Jason    Male   7/31/1992        10:41 PM   94490   13.257
# 44       John    Male    7/1/2002        10:20 AM  134553   13.520
# 47       Jose    Male  10/30/2014         1:39 PM  133032   15.753
# 48        Joe    Male  12/21/1998        10:28 AM  126120   11.373
# 50       Jane  Female   4/19/1999         3:04 PM   91823   16.912
# 53     Joseph    Male   6/19/1984         1:37 AM  110598   12.830
# 57       Jean  Female   7/18/1987         2:59 AM   83141   11.649
# 60    Jessica  Female  10/24/1988        12:15 AM   80028   15.534
# 66   Jonathan    Male  11/15/2004        12:43 PM  110260   10.428
# 69      Julia  Female  11/20/1982         9:52 AM  121400   12.723
# 71     Judith  Female    7/3/2015        12:30 PM  126401    5.923
# 74     Jeremy    Male   6/14/1988        12:00 AM  129460   13.657
# 83     Justin    Male   2/18/1992        12:00 AM   50165   11.458
# 87      Julie  Female  10/26/1997        12:00 AM  102508   12.609
#
#    Senior Management                  Team  Salary in Thousands  Bonus Amount
# 3               True               finance              138.705   12955.04700
# 15             False               product               64.505    5379.07195
# 23             False                 sales               94.490   12526.53930
# 44             False       client services              134.553   18191.56560
# 47              True       client services              133.032   20956.53096
# 48              True       client services              126.120   14343.62760
# 50             False       human resources               91.823   15529.10576
# 53              True                 sales              110.598   14189.72340
# 57              True          distribution               83.141    9685.09509
# 60              True  business development               80.028   12431.54952
# 66             False             marketing              110.260   11497.91280
# 69              True  business development              121.400   15445.72200
# 71              True  business development              126.401    7486.73123
# 74              True       human resources              129.460   17680.35220
# 83              True               finance               50.165    5747.90570
# 87              True                 legal              102.508   12925.23372

# %% [markdown]
# # DATETIME OPERATIONS

# %%
emp_df['Start Date'] = pd.to_datetime(emp_df['Start Date'])

emp_df['Start Year'] = emp_df['Start Date'].dt.year
emp_df['Day of Week'] = emp_df['Start Date'].dt.day_name()

print("\nEmployees who joined in 1993:")
print(emp_df[emp_df['Start Year'] == 1993])
# Out:
# Employees who joined in 1993:
#    First Name  Gender Start Date Last Login Time  Salary  Bonus %  \
# 0     Douglas    Male 1993-08-06        12:42 PM   97308    6.945
# 2       Maria  Female 1993-04-23        11:17 AM  130590   11.858
# 14    Phyllis  Female 1993-10-24         7:29 PM  121162   10.759
# 49      Doris  Female 1993-07-05         5:54 PM   81121    8.969
#
#    Senior Management       Team  Salary in Thousands  Bonus Amount  \
# 0               True  marketing               97.308    6758.04060
# 2              False    finance              130.590   15485.36220
# 14              True      sales              121.162   13035.81958
# 49             False      sales               81.121    7275.74249
#
#     Start Year Day of Week
# 0         1993      Friday
# 2         1993      Friday
# 14        1993      Sunday
# 49        1993      Monday

# %% [markdown]
# # FILTERING / BOOLEAN INDEXING

# %%
print("\nLegal Team Employees:")
print(emp_df[emp_df['Team'] == 'legal'])

print("\nSalary > 120000:")
print(emp_df[emp_df['Salary'] > 120000])

print("\nFemale Senior Management:")
print(emp_df[(emp_df['Gender'] == 'Female') & (emp_df['Senior Management'] == True)])

print("\nFinance OR Product Team:")
print(emp_df[emp_df['Team'].isin(['finance', 'product'])])
# Out:
# Legal Team Employees:
#    First Name  Gender Start Date Last Login Time  Salary  Bonus %  \
# 5      Dennis    Male 1987-04-18         1:35 AM  115163   10.125
# 20     Albert    Male 1995-05-11         3:16 AM  129793    9.789
# 25      Scott    Male 2000-07-20         5:26 PM   79271    7.241
# 34   Benjamin    Male 2005-01-26        10:06 PM   79544   19.333
# 36    Russell    Male 2013-05-10        11:08 PM  133959   16.417
# 59       Carl    Male 1983-05-02         6:04 PM   56437   11.458
# 73    Stephen    Male 1984-01-14        12:00 AM   91278   11.916
# 80    Frances  Female 2002-08-08        12:00 AM  135682   10.222
# 87      Julie  Female 1997-10-26        12:00 AM  102508   12.609
#
#    Senior Management   Team  Salary in Thousands  Bonus Amount  Start Year  \
# 5              False  legal              115.163   11660.25375        1987
# 20              True  legal              129.793   12705.43677        1995
# 25             False  legal               79.271    5740.01311        2000
# 34             False  legal               79.544   15378.24152        2005
# 36             False  legal              133.959   21992.04903        2013
# 59              True  legal               56.437    6466.55146        1983
# 73              True  legal               91.278   10876.68648        1984
# 80              True  legal              135.682   13869.41404        2002
# 87              True  legal              102.508   12925.23372        1997
#
#    Day of Week
# 5     Saturday
# 20    Thursday
# 25    Thursday
# 34   Wednesday
# 36      Friday
# 59      Monday
# 73    Saturday
# 80    Thursday
# 87      Sunday
#
# Salary > 120000:
#    First Name  Gender Start Date Last Login Time  Salary  Bonus %  \
# 2       Maria  Female 1993-04-23        11:17 AM  130590   11.858
# 3       Jerry    Male 2005-03-04         1:00 PM  138705    9.340
# 9      Rachel  Female 2016-02-16         6:53 AM  143642   12.555
# 10      Linda  Female 1981-05-31         8:51 PM  140222    6.333
# 14    Phyllis  Female 1993-10-24         7:29 PM  121162   10.759
# 17      Chris    Male 2014-12-12         1:57 AM  142661    1.388
# 20     Albert    Male 1995-05-11         3:16 AM  129793    9.789
# 24      Frank    Male 2007-01-15        10:45 PM  126782   10.231
# 33      Terry    Male 1981-11-27         6:30 PM  124008   13.464
# 36    Russell    Male 2013-05-10        11:08 PM  133959   16.417
# 41    Mildred  Female 2007-04-26        10:11 PM  139181   16.888
# 43      Laura  Female 2014-07-19         9:23 PM  140371   10.636
# 44       John    Male 2002-07-01        10:20 AM  134553   13.520
# 47       Jose    Male 2014-10-30         1:39 PM  133032   15.753
# 48        Joe    Male 1998-12-21        10:28 AM  126120   11.373
# 56     Sandra  Female 2003-10-11         1:00 AM  140237   13.753
# 61      Henry    Male 2014-11-27         6:05 AM  122603    7.011
# 65    Marilyn  Female 1994-12-11         1:49 PM  148121   11.432
Name  Gender Start Date Last Login Time  Salary  Bonus %  \
# 2       Maria  Female 1993-04-23        11:17 AM  130590   11.858
# 3       Jerry    Male 2005-03-04         1:00 PM  138705    9.340
# 6        Ruby  Female 1987-08-17         4:20 PM   65476   10.012
# 13      Peter    Male 2007-05-21         5:40 AM   81859    7.457
# 15      James    Male 2008-09-02         6:00 AM   64505    8.339
# 39       Paul    Male 2013-05-21         9:08 AM   86438   15.446
# 46     Daniel    Male 2004-10-24         4:04 PM  113502   12.784
# 52     Andrea  Female 1995-07-14         9:16 AM  114948   11.235
# 54      Helen  Female 2000-12-02         2:38 AM   45233   12.449
# 56     Sandra  Female 2003-10-11         1:00 AM  140237   13.753
# 72     Ronald    Male 1997-02-15         3:23 AM  125217   14.204
# 76    Kathryn  Female 1995-10-09        12:00 AM   54337   13.238
# 79    Lillian  Female 1983-06-12        12:00 AM   64164   17.276
# 83     Justin    Male 1992-02-18        12:00 AM   50165   11.458
# 84      Alice  Female 1988-09-03        12:00 AM   63571   15.397
# 92       Lori  Female 1996-10-20        12:00 AM   93346   13.829
# 95      Debra  Female 2009-03-21        12:00 AM  125026    2.253
#
#    Senior Management     Team  Salary in Thousands  Bonus Amount  Start Year  \
# 2              False  finance              130.590   15485.36220        1993
# 3               True  finance              138.705   12955.04700        2005
# 6               True  product               65.476    6555.45712        1987
# 13              True  finance               81.859    6104.22563        2007
# 15             False  product               64.505    5379.07195        2008
# 39             False  product               86.438   13351.21348        2013
# 46              True  finance              113.502   14510.09568        2004
# 52              True  finance              114.948   12914.40780        1995
# 54             False  product               45.233    5631.05617        2000
# 56              True  product              140.237   19286.79461        2003
# 72             False  product              125.217   17785.82268        1997
# 76             False  finance               54.337    7193.13206        1995
# 79             False  product               64.164   11084.97264        1983
# 83              True  finance               50.165    5747.90570        1992
# 84              True  product               63.571    9788.02687        1988
# 92              True  finance               93.346   12908.81834        1996
# 95             False  finance              125.026    2816.83578        2009
#
#    Day of Week
# 2       Friday
# 3       Friday
# 6       Monday
# 13      Monday
# 15     Tuesday
# 39     Tuesday
# 46      Sunday
# 52      Friday
# 54    Saturday
# 56    Saturday
# 72    Saturday
# 76      Monday
# 79      Sunday
# 83     Tuesday
# 84    Saturday
# 92      Sunday
# 95    Saturday

# %% [markdown]
# # GROUPBY ANALYSIS

# %%
print("\nAverage Salary by Team:")
print(emp_df.groupby('Team')['Salary'].mean())

print("\nTotal Bonus by Team:")
print(emp_df.groupby('Team')['Bonus Amount'].sum())

print("\nHighest Salary by Senior Management:")
print(emp_df.groupby('Senior Management')['Salary'].max())
# Out:
# Average Salary by Team:
# Team
# business development    107180.307692
# client services          98408.850000
# distribution             83141.000000
# engineering              95570.000000
# finance                 100275.333333
# human resources          85431.500000
# legal                   102626.111111
# marketing               103356.700000
# no team                  85615.000000
# product                  81855.125000
# sales                   104175.714286
# Name: Salary, dtype: float64
#
# Total Bonus by Team:
# Team
# business development    167862.78604
# client services         198298.38043
# distribution              9685.09509
# engineering              17702.43110
# finance                  90635.83019
# human resources         141732.50381
# legal                   111613.87988
# marketing               106286.93930
# no team                   4619.90218
# product                  88862.41552
# sales                   157710.19710
# Name: Bonus Amount, dtype: float64
#
# Highest Salary by Senior Management:
# Senior Management
# False    143642
# True     148121
# Name: Salary, dtype: int64

# %% [markdown]
# # AGGREGATION

# %%
print("\nTeam Salary Statistics:")
print(emp_df.groupby('Team')['Salary'].agg(['mean','min','max']))

print("\nSalary + Bonus % by Team:")
print(emp_df.groupby('Team')[['Salary','Bonus %']].mean())
# Out:
# Team Salary Statistics:
#                                mean    min     max
# Team
# business development  107180.307692  53733  143642
# client services        98408.850000  42407  142661
# distribution           83141.000000  83141   83141
# engineering            95570.000000  95570   95570
# finance               100275.333333  50165  138705
# human resources        85431.500000  41399  129460
# legal                 102626.111111  56437  135682
# marketing             103356.700000  37598  140371
# no team                85615.000000  61933  109297
# product                81855.125000  45233  140237
# sales                 104175.714286  59495  148121
#
# Salary + Bonus % by Team:
#                              Salary    Bonus %
# Team
# business development  107180.307692  12.395846
# client services        98408.850000  10.570150
# distribution           83141.000000  11.649000
# engineering            95570.000000  18.523000
# finance               100275.333333  10.383556
# human resources        85431.500000  11.674643
# legal                 102626.111111  12.123333
# marketing             103356.700000  10.174500
# no team                85615.000000   3.017000
# product                81855.125000  13.359500
# sales                 104175.714286  10.994214

# %% [markdown]
# # TRANSFORM

# %%
emp_df['Team Average Salary'] = emp_df.groupby('Team')['Salary'].transform('mean')

# %% [markdown]
# # FINAL CASE STUDY

# %%
# Fill missing salary with median
emp_df['Salary'] = emp_df['Salary'].fillna(emp_df['Salary'].median())

# Group by Team & Gender
team_gender = emp_df.groupby(['Team','Gender'])['Salary'].mean()
print("\nTeam + Gender Average Salary:")
print(team_gender)

# Highest paying team
highest_team = emp_df.groupby('Team')['Salary'].mean().sort_values(ascending=False)
print("\nHighest Paying Team:")
print(highest_team.head(1))

print("\n===== PROJECT COMPLETED SUCCESSFULLY =====")
# Out:
# Team + Gender Average Salary:
# Team                  Gender
# business development  Female    113961.777778
#                       Male       91922.000000
# client services       Female     85593.600000
#                       Male      102680.600000
# distribution          Female     83141.000000
# engineering           Female     95570.000000
# finance               Female    103649.400000
#                       Male       96057.750000
# human resources       Female     69213.285714
#                       Male      101649.714286
# legal                 Female    119095.000000
#                       Male       97920.714286
# marketing             Female    115809.600000
#                       Male       90903.800000
# no team               Female    109297.000000
#                       Male       61933.000000
# product               Female     75736.200000
#                       Male       92053.333333
# sales                 Female    110024.200000
#                       Male      100926.555556
# Name: Salary, dtype: float64
#
# Highest Paying Team:
# Team
# business development    107180.307692
# Name: Salary, dtype: float64
#
# ===== PROJECT COMPLETED SUCCESSFULLY =====

# %%
python -m nbconvert --to script "assignment 11.ipynb"
# Out:
#   Cell In[1], line 1
#     python -m nbconvert --to script "assignment 11.ipynb"
#               ^
# SyntaxError: invalid syntax
